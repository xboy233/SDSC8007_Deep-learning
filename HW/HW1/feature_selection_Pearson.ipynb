# %%
import numpy as np
import pandas as pd

# %%
#features selection
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
df = pd.read_csv('./HW1.train.csv')
df.describe()
df.corr()['tested_positive.2'].abs().sort_values(ascending=False)
# Out:
# tested_positive.2         1.000000
# tested_positive.1         0.990832
# tested_positive           0.980552
# hh_cmnty_cli.2            0.876815
# hh_cmnty_cli.1            0.876599
# hh_cmnty_cli              0.875617
# nohh_cmnty_cli.1          0.869555
# nohh_cmnty_cli.2          0.869148
# nohh_cmnty_cli            0.869071
# cli.1                     0.831821
# cli.2                     0.831800
# cli                       0.829946
# ili.1                     0.822430
# ili.2                     0.822049
# ili                       0.821379
# public_transit.2          0.566873
# public_transit.1          0.563867
# public_transit            0.561967
# worried_finances.2        0.448545
# worried_finances.1        0.439872
# worried_finances          0.429935
# shop.2                    0.387290
# shop.1                    0.382573
# shop                      0.377748
# MA                        0.279204
# ID                        0.244703
# UT                        0.233433
# ...
