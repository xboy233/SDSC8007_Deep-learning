# %%
import numpy as np
import pandas as pd

# %%
#features selection
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
df = pd.read_csv('./HW1.train.csv')
df.describe()
df.corr()['tested_positive'].sort_values(ascending=False)
# Out:
# tested_positive           1.000000
# tested_positive.1         0.990788
# tested_positive.2         0.980552
# hh_cmnty_cli              0.876745
# hh_cmnty_cli.1            0.875527
# hh_cmnty_cli.2            0.873391
# nohh_cmnty_cli            0.869236
# nohh_cmnty_cli.1          0.867608
# nohh_cmnty_cli.2          0.865055
# cli                       0.832962
# cli.1                     0.825605
# ili                       0.823088
# cli.2                     0.815694
# ili.1                     0.815242
# ili.2                     0.804498
# worried_finances.2        0.462884
# worried_finances.1        0.455947
# worried_finances          0.448451
# UT                        0.248361
# worried_become_ill.2      0.232439
# ID                        0.230862
# TX                        0.228860
# worried_become_ill.1      0.227623
# worried_become_ill        0.222786
# PA                        0.222104
# OK                        0.195962
# anxious                   0.184092
# anxious.1                 0.171953
# IA                        0.170386
# anxious.2                 0.158076
# SC                        0.128914
# KS                        0.127560
# AL                        0.112923
# WV                        0.108313
# VA                        0.103510
# MS                        0.090491
# work_outside_home.2       0.090310
# work_outside_home.1       0.089481
# work_outside_home         0.087965
# WI                        0.087383
# AR                        0.070219
# felt_isolated.2           0.046134
# felt_isolated             0.045412
# felt_isolated.1           0.045120
# LA                        0.029196
# IN                        0.003895
# large_event              -0.010957
# IL                       -0.014928
# GA                       -0.018711
# large_event.1            -0.018858
# large_event.2            -0.026426
# depressed                -0.032093
# depressed.1              -0.039181
# depressed.2              -0.044363
# MN                       -0.046291
# RI                       -0.053022
# travel_outside_state     -0.076880
# travel_outside_state.1   -0.079502
# OR                       -0.082213
# travel_outside_state.2   -0.082297
# MI                       -0.089800
# wearing_mask.2           -0.091040
# WA                       -0.094214
# wearing_mask.1           -0.095981
# wearing_mask             -0.100993
# FL                       -0.105255
# KY                       -0.115825
# CO                       -0.125341
# AK                       -0.149686
# AZ                       -0.155608
# restaurant               -0.160678
# restaurant.1             -0.163862
# restaurant.2             -0.166776
# CA                       -0.207003
# MD                       -0.209713
# CT                       -0.234776
# spent_time               -0.243056
# id                       -0.244826
# spent_time.1             -0.245967
# spent_time.2             -0.249274
# MA                       -0.278227
# shop                     -0.396469
# shop.1                   -0.399129
# shop.2                   -0.400382
# public_transit           -0.564840
# public_transit.1         -0.565580
# public_transit.2         -0.565919
# MO                             NaN
# NE                             NaN
# NV                             NaN
# NJ                             NaN
# NM                             NaN
# NY                             NaN
# NC                             NaN
# OH                             NaN
# Name: tested_positive, dtype: float64
