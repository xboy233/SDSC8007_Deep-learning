# %% [markdown]
# # Baseline Code for HW1
#
# This is just the baseline code to set up the basic function you need. You need to modify the code yourself to achieve a better result.

# %% [markdown]
# ## Import packages you need

# %%
# PyTorch
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# For data preprocess
import numpy as np
import csv
import os

# For plotting
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

myseed = 666  # set a random seed for reproducibility
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(myseed)
torch.manual_seed(myseed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(myseed)

# %% [markdown]
# ## Basic Function
# Do not modify this part

# %%
def get_device():
    ''' Get device (if GPU is available, use GPU) '''
    return 'cuda' if torch.cuda.is_available() else 'cpu'

def plot_learning_curve(loss_record, title=''):
    ''' Plot learning curve of your DNN (train & dev loss) '''
    total_steps = len(loss_record['train'])
    x_1 = range(total_steps)
    x_2 = x_1[::len(loss_record['train']) // len(loss_record['dev'])]
    figure(figsize=(6, 4))
    plt.plot(x_1, loss_record['train'], c='tab:red', label='train')
    plt.plot(x_2, loss_record['dev'], c='tab:cyan', label='dev')
    plt.ylim(0.0, 5.)
    plt.xlabel('Training steps')
    plt.ylabel('MSE loss')
    plt.title('Learning curve of {}'.format(title))
    plt.legend()
    plt.show()
    
def plot_pred(dv_set, model, device, lim=35., preds=None, targets=None):
    ''' Plot prediction of your DNN '''
    if preds is None or targets is None:
        model.eval()
        preds, targets = [], []
        for x, y in dv_set:
            x, y = x.to(device), y.to(device)
            with torch.no_grad():
                pred = model(x)
                preds.append(pred.detach().cpu())
                targets.append(y.detach().cpu())
        preds = torch.cat(preds, dim=0).numpy()
        targets = torch.cat(targets, dim=0).numpy()

    figure(figsize=(5, 5))
    plt.scatter(targets, preds, c='r', alpha=0.5)
    plt.plot([-0.2, lim], [-0.2, lim], c='b')
    plt.xlim(-0.2, lim)
    plt.ylim(-0.2, lim)
    plt.xlabel('Truth value')
    plt.ylabel('predicted value')
    plt.title('Truth v.s. Prediction')
    plt.show()

# %% [markdown]
# ## Data and Preprocess
# The function below used to:
# 1. Read the csv files into python
# 2. Choose features (you can choose yourself)
# 3. Split data into training and validation sets.
# 4. Normalization

# %%
class Dataprocess(Dataset):
    def __init__(self,
                 path,
                 mode='train',
                 modify=False):
        self.mode = mode

        # Read csv file
        with open(path, 'r') as f:
            data = list(csv.reader(f))
            data = np.array(data[1:])[:, 1:].astype(float)
        
        if modify == False:
            feats = list(range(1,93))
        else:
            # Hint:Feature Selection
            
            
            
            pass

        if mode == 'test':
            # Testing set
            feats = [f+1 for f in feats]
            data = data[:, feats]
            self.data = torch.FloatTensor(data)
        else:
            # Training set
            target = data[:, -1]
            data = data[:, feats]

            # Splitting data into training and validation sets
            if mode == 'train':
                indices = [i for i in range(len(data)) if i % 10 != 0]
            elif mode == 'dev':
                indices = [i for i in range(len(data)) if i % 10 == 0]
            
            # Convert data into PyTorch tensors
            self.data = torch.FloatTensor(data[indices])
            self.target = torch.FloatTensor(target[indices])

        # Normalize features
        self.data[:, 40:] = \
            (self.data[:, 40:] - self.data[:, 40:].mean(dim=0, keepdim=True)) \
            / self.data[:, 40:].std(dim=0, keepdim=True)

        self.dim = self.data.shape[1]

        print('Finished reading the {} set of COVID19 Dataset ({} samples found, each dim = {})'
              .format(mode, len(self.data), self.dim))

    def __getitem__(self, index):
        # Returns one sample at a time
        if self.mode in ['train', 'dev']:
            # For training
            return self.data[index], self.target[index]
        else:
            # For testing
            return self.data[index]

    def __len__(self):
        # Returns the size of the dataset
        return len(self.data)

# %% [markdown]
# ## Dataloader
# Loads data into batches.

# %%
def dataloader(path, mode, batch_size, n_jobs=0, modify=False):
    dataset = Dataprocess(path, mode=mode, modify=modify)
    dataloader = DataLoader(
        dataset, batch_size,
        shuffle=(mode == 'train'), drop_last=False,
        num_workers=n_jobs, pin_memory=True)
    return dataloader

# %% [markdown]
# ## Define DNN by pytorch
# The DNN consists of 2 fully-connected layers with ReLU activation function

# %%
class NeuralNet(nn.Module):
    def __init__(self, input_dim):
        super(NeuralNet, self).__init__()
        
        # Try to modify this DNN to achieve better performance
        self.net = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

        # Loss function MSE
        self.criterion = nn.MSELoss(reduction='mean')

    def forward(self, x):
        ''' Given input of size (batch_size x input_dim), compute output of the network '''
        return self.net(x).squeeze(1)

    def cal_loss(self, pred, target):
        ''' Calculate loss '''
        # You may try regularization here
        
        return self.criterion(pred, target)

# %% [markdown]
# ## Training

# %%
def train(tr_set, dv_set, model, config, device):

    n_epochs = config['n_epochs']  # Maximum number of epochs

    # Setup optimizer
    optimizer = getattr(torch.optim, config['optimizer'])(
        model.parameters(), **config['optim_hparas'])

    min_mse = 1000.
    loss_record = {'train': [], 'dev': []}      # for recording training loss
    early_stop_cnt = 0
    epoch = 0
    while epoch < n_epochs:
        model.train()                           # set model to training mode
        for x, y in tr_set:                     # iterate through the dataloader
            optimizer.zero_grad()               # set gradient to zero
            x, y = x.to(device), y.to(device)   # move data to device (cpu/cuda)
            pred = model(x)                     # forward pass (compute output)
            mse_loss = model.cal_loss(pred, y)  # compute loss
            mse_loss.backward()                 # compute gradient (backpropagation)
            optimizer.step()                    # update model with optimizer
            loss_record['train'].append(mse_loss.detach().cpu().item())

        dev_mse = dev(dv_set, model, device)
        if dev_mse < min_mse:
            # Save model if your model improved
            min_mse = dev_mse
            print('Saving model (epoch = {:4d}, loss = {:.4f})'
                .format(epoch + 1, min_mse))
            torch.save(model.state_dict(), config['save_path'])  # Save model to specified path
            early_stop_cnt = 0
        else:
            early_stop_cnt += 1

        epoch += 1
        loss_record['dev'].append(dev_mse)
        if early_stop_cnt > config['early_stop']:
            break

    print('Finished training after {} epochs'.format(epoch))
    return min_mse, loss_record

# %% [markdown]
# ## Validation

# %%
def dev(dv_set, model, device):
    model.eval()                                # set model to evalutation mode
    total_loss = 0
    for x, y in dv_set:                         # iterate through the dataloader
        x, y = x.to(device), y.to(device)       # move data to device (cpu/cuda)
        with torch.no_grad():                   # disable gradient calculation
            pred = model(x)                     # forward pass (compute output)
            mse_loss = model.cal_loss(pred, y)  # compute loss
        total_loss += mse_loss.detach().cpu().item() * len(x)  # accumulate loss
    total_loss = total_loss / len(dv_set.dataset)              # compute averaged loss

    return total_loss

# %% [markdown]
# ## Testing

# %%
def test(tt_set, model, device):
    model.eval()                                # set model to evalutation mode
    preds = []
    for x in tt_set:                            # iterate through the dataloader
        x = x.to(device)                        # move data to device (cpu/cuda)
        with torch.no_grad():                   # disable gradient calculation
            pred = model(x)                     # forward pass (compute output)
            preds.append(pred.detach().cpu())   # collect prediction
    preds = torch.cat(preds, dim=0).numpy()     # concatenate all predictions and convert to a numpy array
    return preds

# %% [markdown]
# ## Hyper-parameters for DNN

# %%
device = get_device()                 # get the current available device ('cpu' or 'cuda')
os.makedirs('models', exist_ok=True)  # The trained model will be saved to ./models/
modify = False                        # Need selection

# Tune these hyper-parameters to improve your model
config = {
    'n_epochs': 3000,                # maximum number of epochs
    'batch_size': 270,               # mini-batch size for dataloader
    'optimizer': 'SGD',              # optimization algorithm (optimizer in torch.optim)
    'optim_hparas': {                # hyper-parameters for the optimizer (depends on which optimizer you are using)
        'lr': 0.001,                 # learning rate of SGD
    },
    'early_stop': 200,               # early stopping epochs (the number epochs since your model's last improvement)
    'save_path': 'models/model.pth'  # your model will be saved here
}

# %% [markdown]
# ## Read the dataset

# %%
train_path = '../Data/HW1.train.csv'  # path to training data
test_path = '../Data/HW1.test.csv'   # path to testing data

train_set = dataloader(train_path, 'train', config['batch_size'], modify=modify)
validation_set = dataloader(train_path, 'dev', config['batch_size'], modify=modify)
test_set = dataloader(test_path, 'test', config['batch_size'], modify=modify)
# Out:
# Finished reading the train set of COVID19 Dataset (1800 samples found, each dim = 92)
# Finished reading the dev set of COVID19 Dataset (200 samples found, each dim = 92)
# Finished reading the test set of COVID19 Dataset (650 samples found, each dim = 92)

# %% [markdown]
# ## Try to train your DNN

# %%
model = NeuralNet(train_set.dataset.dim).to(device)  # Construct model and move to device

# %%
model_loss, model_loss_record = train(train_set, validation_set, model, config, device)
# Out:
# Saving model (epoch =    1, loss = 253.9166)
# Saving model (epoch =    2, loss = 215.8630)
# Saving model (epoch =    3, loss = 151.7118)
# Saving model (epoch =    4, loss = 81.0847)
# Saving model (epoch =    5, loss = 42.0412)
# Saving model (epoch =    6, loss = 27.4946)
# Saving model (epoch =    7, loss = 22.3139)
# Saving model (epoch =    8, loss = 20.1318)
# Saving model (epoch =    9, loss = 18.9290)
# Saving model (epoch =   10, loss = 18.0333)
# Saving model (epoch =   11, loss = 17.2573)
# Saving model (epoch =   12, loss = 16.5363)
# Saving model (epoch =   13, loss = 15.8874)
# Saving model (epoch =   14, loss = 15.2473)
# Saving model (epoch =   15, loss = 14.6501)
# Saving model (epoch =   16, loss = 14.0852)
# Saving model (epoch =   17, loss = 13.5607)
# Saving model (epoch =   18, loss = 13.0869)
# Saving model (epoch =   19, loss = 12.6134)
# Saving model (epoch =   20, loss = 12.1565)
# Saving model (epoch =   21, loss = 11.7261)
# Saving model (epoch =   22, loss = 11.3329)
# Saving model (epoch =   23, loss = 10.9600)
# Saving model (epoch =   24, loss = 10.6065)
# Saving model (epoch =   25, loss = 10.2650)
# Saving model (epoch =   26, loss = 9.9345)
# Saving model (epoch =   27, loss = 9.6440)
# Saving model (epoch =   28, loss = 9.3099)
# Saving model (epoch =   29, loss = 9.0350)
# Saving model (epoch =   30, loss = 8.7773)
# Saving model (epoch =   31, loss = 8.5330)
# Saving model (epoch =   32, loss = 8.2860)
# Saving model (epoch =   33, loss = 8.0656)
# Saving model (epoch =   34, loss = 7.8581)
# Saving model (epoch =   35, loss = 7.6419)
# Saving model (epoch =   36, loss = 7.4334)
# Saving model (epoch =   37, loss = 7.2278)
# Saving model (epoch =   38, loss = 7.0490)
# Saving model (epoch =   39, loss = 6.8682)
# Saving model (epoch =   40, loss = 6.6754)
# Saving model (epoch =   41, loss = 6.5460)
# Saving model (epoch =   42, loss = 6.3713)
# Saving model (epoch =   43, loss = 6.2272)
# Saving model (epoch =   44, loss = 6.0847)
# Saving model (epoch =   45, loss = 5.9593)
# Saving model (epoch =   46, loss = 5.8055)
# Saving model (epoch =   47, loss = 5.6856)
# Saving model (epoch =   48, loss = 5.5532)
# Saving model (epoch =   49, loss = 5.4349)
# Saving model (epoch =   50, loss = 5.3142)
# Saving model (epoch =   51, loss = 5.2100)
# Saving model (epoch =   52, loss = 5.1172)
# Saving model (epoch =   53, loss = 4.9974)
# Saving model (epoch =   54, loss = 4.8997)
# Saving model (epoch =   55, loss = 4.8151)
# Saving model (epoch =   56, loss = 4.7294)
# Saving model (epoch =   57, loss = 4.6400)
# Saving model (epoch =   58, loss = 4.5463)
# Saving model (epoch =   59, loss = 4.4635)
# Saving model (epoch =   60, loss = 4.4020)
# Saving model (epoch =   61, loss = 4.3098)
# Saving model (epoch =   62, loss = 4.2402)
# Saving model (epoch =   63, loss = 4.1555)
# Saving model (epoch =   64, loss = 4.0743)
# Saving model (epoch =   65, loss = 4.0329)
# Saving model (epoch =   66, loss = 3.9529)
# Saving model (epoch =   67, loss = 3.8982)
# Saving model (epoch =   68, loss = 3.8289)
# Saving model (epoch =   69, loss = 3.7636)
# Saving model (epoch =   70, loss = 3.7065)
# Saving model (epoch =   71, loss = 3.6608)
# Saving model (epoch =   72, loss = 3.6082)
# Saving model (epoch =   73, loss = 3.5414)
# Saving model (epoch =   74, loss = 3.5073)
# Saving model (epoch =   75, loss = 3.4576)
# Saving model (epoch =   76, loss = 3.4066)
# Saving model (epoch =   77, loss = 3.3647)
# Saving model (epoch =   78, loss = 3.3144)
# Saving model (epoch =   79, loss = 3.2619)
# Saving model (epoch =   80, loss = 3.2313)
# Saving model (epoch =   81, loss = 3.1682)
# Saving model (epoch =   82, loss = 3.1169)
# Saving model (epoch =   83, loss = 3.0810)
# Saving model (epoch =   84, loss = 3.0611)
# Saving model (epoch =   85, loss = 3.0110)
# Saving model (epoch =   86, loss = 2.9781)
# Saving model (epoch =   87, loss = 2.9353)
# Saving model (epoch =   88, loss = 2.9133)
# Saving model (epoch =   89, loss = 2.8712)
# Saving model (epoch =   90, loss = 2.8598)
# Saving model (epoch =   91, loss = 2.8408)
# Saving model (epoch =   92, loss = 2.8080)
# Saving model (epoch =   93, loss = 2.7637)
# Saving model (epoch =   94, loss = 2.7455)
# Saving model (epoch =   95, loss = 2.7124)
# Saving model (epoch =   96, loss = 2.6894)
# Saving model (epoch =   97, loss = 2.6483)
# Saving model (epoch =   98, loss = 2.6155)
# Saving model (epoch =  100, loss = 2.5714)
# Saving model (epoch =  101, loss = 2.5628)
# Saving model (epoch =  102, loss = 2.5494)
# Saving model (epoch =  103, loss = 2.5025)
# Saving model (epoch =  104, loss = 2.4921)
# Saving model (epoch =  105, loss = 2.4609)
# Saving model (epoch =  106, loss = 2.4392)
# Saving model (epoch =  107, loss = 2.4099)
# Saving model (epoch =  108, loss = 2.3980)
# Saving model (epoch =  109, loss = 2.3930)
# Saving model (epoch =  110, loss = 2.3767)
# Saving model (epoch =  111, loss = 2.3525)
# Saving model (epoch =  112, loss = 2.3185)
# Saving model (epoch =  113, loss = 2.3133)
# Saving model (epoch =  114, loss = 2.3004)
# Saving model (epoch =  115, loss = 2.2980)
# Saving model (epoch =  116, loss = 2.2378)
# Saving model (epoch =  117, loss = 2.2360)
# Saving model (epoch =  118, loss = 2.2298)
# Saving model (epoch =  119, loss = 2.2254)
# Saving model (epoch =  120, loss = 2.1866)
# Saving model (epoch =  121, loss = 2.1650)
# Saving model (epoch =  122, loss = 2.1531)
# Saving model (epoch =  123, loss = 2.1404)
# Saving model (epoch =  125, loss = 2.0968)
# Saving model (epoch =  128, loss = 2.0684)
# Saving model (epoch =  130, loss = 2.0509)
# Saving model (epoch =  131, loss = 2.0256)
# Saving model (epoch =  132, loss = 2.0071)
# Saving model (epoch =  133, loss = 1.9993)
# Saving model (epoch =  134, loss = 1.9829)
# Saving model (epoch =  136, loss = 1.9686)
# Saving model (epoch =  137, loss = 1.9556)
# Saving model (epoch =  138, loss = 1.9354)
# Saving model (epoch =  141, loss = 1.9316)
# Saving model (epoch =  142, loss = 1.9213)
# Saving model (epoch =  143, loss = 1.8992)
# Saving model (epoch =  145, loss = 1.8634)
# Saving model (epoch =  148, loss = 1.8628)
# Saving model (epoch =  149, loss = 1.8486)
# Saving model (epoch =  150, loss = 1.8284)
# Saving model (epoch =  153, loss = 1.8143)
# Saving model (epoch =  155, loss = 1.7803)
# Saving model (epoch =  156, loss = 1.7800)
# Saving model (epoch =  158, loss = 1.7542)
# Saving model (epoch =  160, loss = 1.7537)
# Saving model (epoch =  161, loss = 1.7338)
# Saving model (epoch =  162, loss = 1.7188)
# Saving model (epoch =  165, loss = 1.7174)
# Saving model (epoch =  166, loss = 1.6971)
# Saving model (epoch =  170, loss = 1.6680)
# Saving model (epoch =  172, loss = 1.6568)
# Saving model (epoch =  176, loss = 1.6427)
# Saving model (epoch =  178, loss = 1.6330)
# Saving model (epoch =  179, loss = 1.6273)
# Saving model (epoch =  180, loss = 1.6110)
# Saving model (epoch =  181, loss = 1.5921)
# Saving model (epoch =  185, loss = 1.5831)
# Saving model (epoch =  186, loss = 1.5778)
# Saving model (epoch =  187, loss = 1.5766)
# Saving model (epoch =  188, loss = 1.5528)
# Saving model (epoch =  190, loss = 1.5483)
# Saving model (epoch =  192, loss = 1.5400)
# Saving model (epoch =  193, loss = 1.5341)
# Saving model (epoch =  195, loss = 1.5232)
# Saving model (epoch =  201, loss = 1.5218)
# Saving model (epoch =  202, loss = 1.5088)
# Saving model (epoch =  203, loss = 1.4961)
# Saving model (epoch =  204, loss = 1.4939)
# Saving model (epoch =  205, loss = 1.4901)
# Saving model (epoch =  206, loss = 1.4759)
# Saving model (epoch =  207, loss = 1.4730)
# Saving model (epoch =  211, loss = 1.4654)
# Saving model (epoch =  212, loss = 1.4506)
# Saving model (epoch =  215, loss = 1.4374)
# Saving model (epoch =  217, loss = 1.4242)
# Saving model (epoch =  218, loss = 1.4219)
# Saving model (epoch =  222, loss = 1.4202)
# Saving model (epoch =  224, loss = 1.4182)
# Saving model (epoch =  226, loss = 1.4023)
# Saving model (epoch =  227, loss = 1.3951)
# Saving model (epoch =  228, loss = 1.3916)
# Saving model (epoch =  229, loss = 1.3801)
# Saving model (epoch =  230, loss = 1.3788)
# Saving model (epoch =  231, loss = 1.3733)
# Saving model (epoch =  233, loss = 1.3701)
# Saving model (epoch =  235, loss = 1.3617)
# Saving model (epoch =  236, loss = 1.3541)
# Saving model (epoch =  238, loss = 1.3400)
# Saving model (epoch =  246, loss = 1.3347)
# Saving model (epoch =  247, loss = 1.3226)
# Saving model (epoch =  250, loss = 1.3204)
# Saving model (epoch =  252, loss = 1.3141)
# Saving model (epoch =  253, loss = 1.2983)
# Saving model (epoch =  257, loss = 1.2979)
# Saving model (epoch =  259, loss = 1.2836)
# Saving model (epoch =  261, loss = 1.2831)
# Saving model (epoch =  263, loss = 1.2704)
# Saving model (epoch =  264, loss = 1.2695)
# Saving model (epoch =  267, loss = 1.2637)
# Saving model (epoch =  270, loss = 1.2536)
# Saving model (epoch =  277, loss = 1.2519)
# Saving model (epoch =  278, loss = 1.2449)
# Saving model (epoch =  281, loss = 1.2436)
# Saving model (epoch =  282, loss = 1.2336)
# Saving model (epoch =  283, loss = 1.2281)
# Saving model (epoch =  289, loss = 1.2228)
# Saving model (epoch =  291, loss = 1.2200)
# Saving model (epoch =  293, loss = 1.2123)
# Saving model (epoch =  294, loss = 1.2016)
# Saving model (epoch =  302, loss = 1.1971)
# Saving model (epoch =  305, loss = 1.1850)
# Saving model (epoch =  306, loss = 1.1801)
# Saving model (epoch =  310, loss = 1.1786)
# Saving model (epoch =  311, loss = 1.1643)
# Saving model (epoch =  317, loss = 1.1614)
# Saving model (epoch =  318, loss = 1.1601)
# Saving model (epoch =  320, loss = 1.1581)
# Saving model (epoch =  325, loss = 1.1442)
# Saving model (epoch =  329, loss = 1.1397)
# Saving model (epoch =  330, loss = 1.1386)
# Saving model (epoch =  331, loss = 1.1354)
# Saving model (epoch =  339, loss = 1.1223)
# Saving model (epoch =  342, loss = 1.1167)
# Saving model (epoch =  343, loss = 1.1090)
# Saving model (epoch =  348, loss = 1.1051)
# Saving model (epoch =  350, loss = 1.1051)
# Saving model (epoch =  351, loss = 1.0972)
# Saving model (epoch =  358, loss = 1.0914)
# Saving model (epoch =  364, loss = 1.0896)
# Saving model (epoch =  366, loss = 1.0771)
# Saving model (epoch =  382, loss = 1.0715)
# Saving model (epoch =  384, loss = 1.0704)
# Saving model (epoch =  389, loss = 1.0565)
# Saving model (epoch =  391, loss = 1.0506)
# Saving model (epoch =  401, loss = 1.0495)
# Saving model (epoch =  402, loss = 1.0454)
# Saving model (epoch =  407, loss = 1.0428)
# Saving model (epoch =  408, loss = 1.0410)
# Saving model (epoch =  419, loss = 1.0334)
# Saving model (epoch =  421, loss = 1.0295)
# Saving model (epoch =  434, loss = 1.0263)
# Saving model (epoch =  435, loss = 1.0119)
# Saving model (epoch =  459, loss = 1.0091)
# Saving model (epoch =  465, loss = 1.0020)
# Saving model (epoch =  466, loss = 1.0015)
# Saving model (epoch =  470, loss = 1.0004)
# Saving model (epoch =  471, loss = 0.9886)
# Saving model (epoch =  481, loss = 0.9868)
# Saving model (epoch =  483, loss = 0.9844)
# Saving model (epoch =  497, loss = 0.9822)
# Saving model (epoch =  498, loss = 0.9779)
# Saving model (epoch =  506, loss = 0.9712)
# Saving model (epoch =  515, loss = 0.9675)
# Saving model (epoch =  519, loss = 0.9652)
# Saving model (epoch =  523, loss = 0.9616)
# Saving model (epoch =  532, loss = 0.9558)
# Saving model (epoch =  536, loss = 0.9556)
# Saving model (epoch =  547, loss = 0.9545)
# Saving model (epoch =  554, loss = 0.9541)
# Saving model (epoch =  556, loss = 0.9519)
# Saving model (epoch =  563, loss = 0.9439)
# Saving model (epoch =  564, loss = 0.9421)
# Saving model (epoch =  573, loss = 0.9404)
# Saving model (epoch =  588, loss = 0.9324)
# Saving model (epoch =  597, loss = 0.9231)
# Saving model (epoch =  608, loss = 0.9227)
# Saving model (epoch =  625, loss = 0.9209)
# Saving model (epoch =  628, loss = 0.9184)
# Saving model (epoch =  648, loss = 0.9168)
# Saving model (epoch =  656, loss = 0.9161)
# Saving model (epoch =  657, loss = 0.9075)
# Saving model (epoch =  661, loss = 0.9021)
# Saving model (epoch =  696, loss = 0.8971)
# Saving model (epoch =  704, loss = 0.8937)
# Saving model (epoch =  719, loss = 0.8909)
# Saving model (epoch =  720, loss = 0.8839)
# Saving model (epoch =  758, loss = 0.8810)
# Saving model (epoch =  779, loss = 0.8765)
# Saving model (epoch =  793, loss = 0.8690)
# Saving model (epoch =  805, loss = 0.8659)
# Saving model (epoch =  840, loss = 0.8617)
# Saving model (epoch =  880, loss = 0.8461)
# Saving model (epoch =  948, loss = 0.8381)
# Saving model (epoch =  970, loss = 0.8279)
# Saving model (epoch = 1026, loss = 0.8263)
# Saving model (epoch = 1048, loss = 0.8251)
# Saving model (epoch = 1067, loss = 0.8216)
# Saving model (epoch = 1084, loss = 0.8184)
# Saving model (epoch = 1112, loss = 0.8155)
# Saving model (epoch = 1129, loss = 0.8141)
# Saving model (epoch = 1155, loss = 0.8132)
# Saving model (epoch = 1183, loss = 0.8121)
# Saving model (epoch = 1196, loss = 0.8112)
# Saving model (epoch = 1201, loss = 0.8095)
# Saving model (epoch = 1215, loss = 0.8086)
# Saving model (epoch = 1222, loss = 0.8035)
# Saving model (epoch = 1224, loss = 0.8025)
# Saving model (epoch = 1288, loss = 0.7954)
# Saving model (epoch = 1315, loss = 0.7917)
# Saving model (epoch = 1367, loss = 0.7910)
# Saving model (epoch = 1385, loss = 0.7898)
# Saving model (epoch = 1436, loss = 0.7811)
# Saving model (epoch = 1602, loss = 0.7810)
# Saving model (epoch = 1633, loss = 0.7794)
# Saving model (epoch = 1644, loss = 0.7750)
# Saving model (epoch = 1696, loss = 0.7738)
# Saving model (epoch = 1739, loss = 0.7718)
# Saving model (epoch = 1769, loss = 0.7711)
# Saving model (epoch = 1778, loss = 0.7701)
# Saving model (epoch = 1789, loss = 0.7660)
# Saving model (epoch = 1872, loss = 0.7614)
# Saving model (epoch = 1879, loss = 0.7611)
# Saving model (epoch = 1931, loss = 0.7609)
# Saving model (epoch = 2003, loss = 0.7573)
# Saving model (epoch = 2072, loss = 0.7550)
# Saving model (epoch = 2120, loss = 0.7545)
# Saving model (epoch = 2205, loss = 0.7533)
# Saving model (epoch = 2236, loss = 0.7522)
# Saving model (epoch = 2311, loss = 0.7516)
# Saving model (epoch = 2379, loss = 0.7509)
# Saving model (epoch = 2450, loss = 0.7503)
# Saving model (epoch = 2520, loss = 0.7480)
# Saving model (epoch = 2618, loss = 0.7477)
# Saving model (epoch = 2633, loss = 0.7442)
# Finished training after 2834 epochs

# %%
plot_learning_curve(model_loss_record, title='deep model')

# %%
del model
model = NeuralNet(train_set.dataset.dim).to(device)
ckpt = torch.load(config['save_path'], map_location='cpu')  # Load your best model
model.load_state_dict(ckpt)
plot_pred(validation_set, model, device)  # Show prediction on the validation set

# %% [markdown]
# ## Testing
# Get the prediction result and save it to csv file named 'prediction.csv'

# %%
def save_pred(preds, file):
    print('Saving results to {}'.format(file))
    with open(file, 'w') as fp:
        writer = csv.writer(fp)
        writer.writerow(['id', 'tested_positive'])
        for i, p in enumerate(preds):
            writer.writerow([i, p])

preds = test(test_set, model, device)  # predict COVID-19 cases with your model
save_pred(preds, 'prediction.csv')         # save prediction file to pred.csv
# Out:
# Saving results to prediction.csv

# %% [markdown]
# ## Hints for better result
# * Feature selection
# * DNN architecture
# * Training (mini-batch/optimizer/learning rate)
# * Regularization
